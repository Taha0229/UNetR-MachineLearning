# %%
# %cd ..
# %pwd

# %%
from UNetRMultiClass.utils.common import decodeImage, encodeImageIntoBase64

# %%
st = encodeImageIntoBase64("research/1632931456656.jpg")

# %%
type(st)
# Out:
# bytes

# %%
st
# Out:
# b'...'
